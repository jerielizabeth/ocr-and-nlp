# %%
# %%bash
#
# source ~/.bashrc
#
# SPARK_SUBMIT_ARGS='--master local[12] --driver-memory 10G --executor-memory 10G' passim "../data/json_data.json" "../data/passim_output_bible/"
# Out:
# :: loading settings :: url = jar:file:/Applications/spark-3.1.2-bin-hadoop2.7/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/jeriwieringa/.ivy2/cache
# The jars for the packages stored in: /Users/jeriwieringa/.ivy2/jars
# com.github.scopt#scopt_2.12 added as a dependency
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-e6a9eb6e-244f-4fee-ac7b-9326e24bf4fd;1.0
# 	confs: [default]
# 	found com.github.scopt#scopt_2.12;3.5.0 in central
# 	found graphframes#graphframes;0.8.0-spark3.0-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 240ms :: artifacts dl 3ms
# 	:: modules in use:
# 	com.github.scopt#scopt_2.12;3.5.0 from central in [default]
# 	graphframes#graphframes;0.8.0-spark3.0-s_2.12 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# ...

# %%
# %%bash
#
# source ~/.bashrc
#
# SPARK_SUBMIT_ARGS='--master local[12] --driver-memory 10G --executor-memory 10G' Passim -m 3 "../data/json_data.json" "../data/passim_output_bible_min3/"
# Out:
# :: loading settings :: url = jar:file:/Applications/spark-3.1.2-bin-hadoop2.7/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/jeriwieringa/.ivy2/cache
# The jars for the packages stored in: /Users/jeriwieringa/.ivy2/jars
# com.github.scopt#scopt_2.12 added as a dependency
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ae0dc63b-7cc9-4479-9d71-aceb3dd9f051;1.0
# 	confs: [default]
# 	found com.github.scopt#scopt_2.12;3.5.0 in central
# 	found graphframes#graphframes;0.8.0-spark3.0-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 223ms :: artifacts dl 4ms
# 	:: modules in use:
# 	com.github.scopt#scopt_2.12;3.5.0 from central in [default]
# 	graphframes#graphframes;0.8.0-spark3.0-s_2.12 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# ...
