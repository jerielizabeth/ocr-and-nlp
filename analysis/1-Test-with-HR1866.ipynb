# %% [markdown]
# # Test of Standard NLP tasks with HR from 1866
#
# After correcting the OCR for HR18660801-V01-01, I am testing the performance of different nlp tasks and libraries on the hand-typed and OCRed texts. At time of work, I had not verified the manually corrected text, so there are likely transcription errors remaining. However, all layout and major recognition errors have been addressed.
#
# For this test, I am going to run through a few standard NLP tasks:
#
# - POS tagging
# - Entity Tagging
# - Tokenization:
#     - sentence
#     - word
#     - phrases
# - lemmatization
#
# Also hope to test with a LM such as BERT.

# %% [markdown]
# First library to test will be SpaCy, using the large language model.

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# Load corrected texts from data directory

# %%
import os

data_dir = "/Users/jeriwieringa/Documents/Research/ocr-and-nlp/data/text/"

files_list = os.listdir(os.path.join(data_dir, "manually-corrected"))

documents = {}

for filename in sorted(files_list):
    if filename.startswith("HR1866"):
#         print(filename)
        with open(os.path.join(data_dir, "manually-corrected", filename), "r") as f:
            content = f.read()
        documents[filename] = content

# %%
documents['HR18660801-V01-01-p1.txt']
# Out:
# '# THE Health Reformer. \nOUR PHYSICIAN, NATURE: OBEY AND LIVE.\nVOL. 1. BATTLE CREEK, MICH., AUGUST, 1866. NO. 1. \nTHE HEALTH REFORMER, \nPUBLISHED MONTHLY AT\nThe Western Health-Reform Institute\nBATTLE CREEK, MICH.,\nH. S. LAY, M.D., EDITOR\nTerms: One Dollar per Year, invariably in Advance.\nAddress Dr. H. S. LAY, Battle Creek, Michigan.\n\n## Original Articles.\n\n## DIGESTION.\n## BY J. H. GINLEY, M.D.\n\nDigestion is that process by which\nfood is reduced to a form in which it can\nbe absorbed and taken up into the blood.\nThis is the way that food builds up the \nwaste constantly going on in the body. \nThis process is accomplished, 1st. By the \nteeth. 2nd. By the saliva. 3d. By the \nmucous membrane. 4th. By the gastric  \njuice. 5th. By the bile; and 6th. By \nthe pancreatic juice. \n\nAs the food consists of a mixture of\nvarious kinds, having different physical \nand chemical properties, so also these \npeculiar fluids differ in kind, quality, and\nchemical action, from each other. \n\nAs the food passes through the intestines \nfrom above downward, those parts \nof it which become reduced to a liquid \nstate, are successively removed by absorption, \nand taken up into the blood\nwhile the remaining portion, which is in-digestible, \ntogether with the intestinal \nsecretions, acquires a firmer consistency \nowing to the absorption of the fluids, and \nis finally discharged as detrite material, \nby the vermicular action of the intestines. \n\nIn the lower order of animals, the digestive\napparatus is more complex than\nin man. The fowl has three stomachs, \nwhile some of the higher order have four;\nwhile man, the head of the animal creation, \nhas but two. There is, however, a great\nsimilarity between the animal digestive\nsystem and that of man. In the human\nspecies, although the digestive apparatus\nis simpler than in animals, still it is quite\ncomplicated. The alimentary canal is\ndivided into different cavities which communicate\nwith each other by narrow openings.\n\nAt its commencement, we find the cavity\nof the mouth guarded at its posterior\nextremity, by a muscular valve of the \nisthmus of the fauces. Through the œsophagus\nit communicates iwth the stomach,\nwhich is guarded at either extremity\nby circular folds of muscular fibres, called\nrespectively, the cardiac and pyloric orifices;\nthen come the small intestines under\ndifferent forms and names, owing to their\nrespective structures. Thus we have the\nduodenum, jejunum and ileum.\n\nIn the duodenum, we have the biliary \nand pancreatic ducts, and lastly the small\nintestines together with the larger ones,\nseparated from the smaller by the ileocoecal\nvalve, which is liable to become\nclosed up by indigestible substances lodging\nin it, causing death. Next are the\nlarger intestines, which are named respectively\nthe ascending transverse, and\ndescending colon, at the latter end of\nwhich is a strong muscular band called\nthe sphincter, and which becomes diseased\nto an intense degree in piles (hemorrhoids).\n\nHaving thus given a brief description\nof the digestive organs, in order to better\nunderstand their uses, let us glance at the \nvery interesting process of digestion.\nWhen food is introduced into the mouth,\nthere is a process of secretion going on \nwhich continues more or less through the\nentire digestive tube. The teeth are set'

# %% [markdown]
# Demo with one document

# %%
doc = nlp(documents['HR18660801-V01-01-p1.txt'])

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# VOL. DATE
# 1 CARDINAL
# BATTLE CREEK LOC
# MICH GPE
# AUGUST DATE
# 1866 DATE
# 1 CARDINAL
# MONTHLY DATE
# The Western Health-Reform Institute ORG
# BATTLE CREEK GPE
# MICH GPE
# H. S. LAY PERSON
# M.D. GPE
# One Dollar MONEY
# H. S. LAY PERSON
# Battle Creek GPE
# Michigan GPE
# ## DIGESTION MONEY
# ## MONEY
# M.D.
#
#  ORG
# 1st DATE
# 2nd DATE
# 3d CARDINAL
# 4th ORDINAL
# 5th ORDINAL
# 6th ORDINAL
# three CARDINAL
# four CARDINAL
# two CARDINAL
# œsophagus GPE

# %%
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['THE Health Reformer', 'OUR PHYSICIAN', 'NATURE', 'VOL.', 'BATTLE CREEK', 'MICH.', 'THE HEALTH REFORMER', 'PUBLISHED MONTHLY', 'The Western Health-Reform Institute\nBATTLE CREEK', ',\nH. S. LAY', 'EDITOR', 'Terms', 'One Dollar', 'Year', 'Advance', 'Address', 'Dr. H. S. LAY', 'Battle Creek', '## Original Articles', '## DIGESTION', 'J. H. GINLEY', 'M.D.', 'Digestion', 'that process', 'food', 'a form', 'it', 'the blood', 'the way', 'food', 'the \nwaste', 'the body', 'This process', 'the \nteeth', 'the saliva', '3d', 'the \nmucous membrane', 'the gastric  \njuice', 'the bile', '6th', 'the pancreatic juice', 'the food', 'a mixture', 'various kinds', 'different physical \nand chemical properties', 'these \npeculiar fluids', 'kind', 'quality', 'chemical action', 'the food', 'the intestines', 'those parts', 'it', 'a liquid \nstate', 'absorption', 'the blood', 'the remaining portion', 'the intestinal \nsecretions', 'a firmer consistency', 'the absorption', 'the fluids', 'detrite material', 'the vermicular action', 'the intestines', 'the lower order', 'animals', 'the digestive\napparatus', 'man', 'The fowl', 'three stomachs', 'the higher order', 'man', 'the head', 'the animal creation', 'a great\nsimilarity', 'the animal digestive\nsystem', 'man', 'the human\nspecies', 'the digestive apparatus', 'animals', 'it', 'The alimentary canal', 'different cavities', 'narrow openings', 'its commencement', 'we', 'the cavity', 'the mouth', 'its posterior\nextremity', 'a muscular valve', 'the \nisthmus', 'the fauces', 'the œsophagus', 'it', 'the stomach', 'either extremity', 'circular folds', 'muscular fibres', 'the cardiac and pyloric orifices', 'the small intestines', 'different forms', 'names', 'their\nrespective structures', 'we', 'the\nduodenum', 'jejunum', 'ileum', 'the duodenum', 'we', 'the biliary \nand pancreatic ducts', 'lastly the small\nintestines', 'the larger ones', 'the ileocoecal\nvalve', 'indigestible substances', 'it', 'death', 'the\nlarger intestines', 'the ascending transverse', 'colon', 'the latter end', 'a strong muscular band', 'the sphincter', 'an intense degree', 'piles', 'hemorrhoids', 'a brief description', 'the digestive organs', 'order', 'their uses', 'us', 'the \nvery interesting process', 'digestion', 'food', 'the mouth', 'a process', 'secretion', 'the\nentire digestive tube', 'The teeth']
# Verbs: ['obey', 'live', 'publish', 'reduce', 'can', 'absorb', 'take', 'build', 'go', 'accomplish', 'consist', 'have', 'differ', 'pass', 'become', 'reduce', 'remove', 'take', 'remain', 'acquire', 'owe', 'discharge', 'divide', 'communicate', 'find', 'guard', 'communicate', 'guard', 'call', 'come', 'owe', 'separate', 'become', 'close', 'lodge', 'cause', 'name', 'ascend', 'descend', 'call', 'become', 'have', 'give', 'understand', 'let', 'glance', 'introduce', 'go', 'continue', 'set']

# %%
doc_verbs = [token.lemma_ for token in doc if token.pos_ == "VERB"]

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# # # PUNCT NFP ROOT # False False
# THE the DET DT det XXX True True
# Health Health PROPN NNP compound Xxxxx True False
# Reformer Reformer PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# OUR our DET PRP$ poss XXX True True
# PHYSICIAN physician NOUN NN ROOT XXXX True False
# , , PUNCT , punct , False False
# NATURE nature NOUN NN appos XXXX True False
# : : PUNCT : punct : False False
# OBEY obey VERB VB appos XXXX True False
# AND and CCONJ CC cc XXX True True
# LIVE live VERB VB conj XXXX True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# VOL VOL PROPN NNP dep XXX True False
# . . PROPN NNP ROOT . False False
# 1 1 NUM CD ROOT d False False
# . . PUNCT . punct . False False
# BATTLE BATTLE PROPN NNP compound XXXX True False
# CREEK CREEK PROPN NNP ROOT XXXX True False
# , , PUNCT , punct , False False
# MICH MICH PROPN NNP dep XXXX True False
# . . PROPN NNP appos . False False
# , , PUNCT , punct , False False
# AUGUST AUGUST PROPN NNP npadvmod XXXX True False
# , , PUNCT , punct , False False
# 1866 1866 NUM CD npadvmod dddd False False
# . . PUNCT . punct . False False
# NO no INTJ UH ROOT XX True True
# . . NOUN NN punct . False False
# 1 1 NUM CD dep d False False
# . . PUNCT . ROOT . False False
#
#
#  SPACE _SP
#  False False
# THE the DET DT det XXX True True
# HEALTH health NOUN NN compound XXXX True False
# REFORMER reformer NOUN NN ROOT XXXX True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# PUBLISHED publish VERB VBD amod XXXX True False
# MONTHLY MONTHLY PROPN NNP appos XXXX True False
# AT at ADP IN ROOT XX True True
#
#
#  SPACE _SP
#  False False
# The the DET DT det Xxx True True
# Western Western PROPN NNP compound Xxxxx True False
# Health Health PROPN NNP compound Xxxxx True False
# - - PUNCT HYPH punct - False False
# Reform Reform PROPN NNP compound Xxxxx True False
# Institute Institute PROPN NNP nmod Xxxxx True False
#
#
#  SPACE _SP
#  False False
# BATTLE BATTLE PROPN NNP compound XXXX True False
# CREEK CREEK PROPN NNP ROOT XXXX True False
# , , PUNCT , punct , False False
# MICH MICH PROPN NNP dep XXXX True False
# . . PROPN NNP punct . False False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# H. H. PROPN NNP compound X. False False
# S. S. PROPN NNP compound X. False False
# LAY LAY PROPN NNP ROOT XXX True False
# , , PUNCT , punct , False False
# M.D. M.D. PROPN NNP npadvmod X.X. False False
# , , PUNCT , punct , False False
# EDITOR editor NOUN NN appos XXXX True False
#
#
#  SPACE _SP
#  False False
# Terms term NOUN NNS ROOT Xxxxx True False
# : : PUNCT : punct : False False
# One one NUM CD nummod Xxx True True
# Dollar dollar NOUN NN ROOT Xxxxx True False
# per per ADP IN prep xxx True True
# Year year NOUN NN pobj Xxxx True False
# , , PUNCT , punct , False False
# invariably invariably ADV RB advmod xxxx True False
# in in ADP IN prep xx True True
# Advance Advance PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# Address Address PROPN NNP ROOT Xxxxx True False
# Dr. Dr. PROPN NNP compound Xx. False False
# H. H. PROPN NNP compound X. False False
# S. S. PROPN NNP compound X. False False
# LAY LAY PROPN NNP dobj XXX True False
# , , PUNCT , punct , False False
# Battle Battle PROPN NNP compound Xxxxx True False
# Creek Creek PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# Michigan Michigan PROPN NNP npadvmod Xxxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# # # NOUN NN quantmod # False False
# # # NOUN NN nmod # False False
# Original original ADJ JJ amod Xxxxx True False
# Articles article NOUN NNS ROOT Xxxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# # # NOUN NN quantmod # False False
# # # NOUN NN nummod # False False
# DIGESTION digestion NOUN NN ROOT XXXX True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# # # NOUN NN dep # False False
# # # NOUN NN intj # False False
# BY by ADP IN ROOT XX True True
# J. J. PROPN NNP compound X. False False
# H. H. PROPN NNP compound X. False False
# GINLEY GINLEY PROPN NNP pobj XXXX True False
# , , PUNCT , punct , False False
# M.D. M.D. PROPN NNP appos X.X. False False
#
#
#
#
#  SPACE _SP
#
#  False False
# Digestion digestion NOUN NN nsubj Xxxxx True False
# is be AUX VBZ ROOT xx True True
# that that DET DT det xxxx True True
# process process NOUN NN attr xxxx True False
# by by ADP IN prep xx True True
# which which DET WDT pobj xxxx True True
#
#
#  SPACE _SP
#  False False
# food food NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
# reduced reduce VERB VBN relcl xxxx True False
# to to ADP IN prep xx True True
# a a DET DT det x True True
# form form NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# which which DET WDT pobj xxxx True True
# it -PRON- PRON PRP nsubjpass xx True True
# can can VERB MD aux xxx True True
#
#
#  SPACE _SP
#  False False
# be be AUX VB auxpass xx True True
# absorbed absorb VERB VBN relcl xxxx True False
# and and CCONJ CC cc xxx True True
# taken take VERB VBN conj xxxx True False
# up up ADP RP prt xx True True
# into into ADP IN prep xxxx True True
# the the DET DT det xxx True True
# blood blood NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# This this DET DT nsubj Xxxx True True
# is be AUX VBZ ROOT xx True True
# the the DET DT det xxx True True
# way way NOUN NN attr xxx True False
# that that DET WDT advmod xxxx True True
# food food NOUN NN nsubj xxxx True False
# builds build VERB VBZ relcl xxxx True False
# up up ADP RP prt xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# waste waste NOUN NN dobj xxxx True False
# constantly constantly ADV RB advmod xxxx True False
# going go VERB VBG advcl xxxx True False
# on on ADP RP prt xx True True
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# body body NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# This this DET DT det Xxxx True True
# process process NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
# accomplished accomplish VERB VBN ROOT xxxx True False
# , , PUNCT , punct , False False
# 1st 1st NOUN NN npadvmod dxx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# teeth tooth NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# 2nd 2nd ADJ JJ ROOT dxx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
# the the DET DT det xxx True True
# saliva saliva NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# 3d 3d PROPN NNP ROOT dx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# mucous mucous ADJ JJ amod xxxx True False
# membrane membrane NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# 4th 4th X LS ROOT dxx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
# the the DET DT det xxx True True
# gastric gastric ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# juice juice NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# 5th 5th ADJ JJ ROOT dxx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
# the the DET DT det xxx True True
# bile bile NOUN NN pobj xxxx True False
# ; ; PUNCT : punct ; False False
# and and CCONJ CC cc xxx True True
# 6th 6th NOUN NN conj dxx False False
# . . PUNCT . punct . False False
# By by ADP IN ROOT Xx True True
#
#
#  SPACE _SP
#  False False
# the the DET DT det xxx True True
# pancreatic pancreatic ADJ JJ amod xxxx True False
# juice juice NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# As as SCONJ IN mark Xx True True
# the the DET DT det xxx True True
# food food NOUN NN nsubj xxxx True False
# consists consist VERB VBZ advcl xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# mixture mixture NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
#
#
#  SPACE _SP
#  False False
# various various ADJ JJ amod xxxx True True
# kinds kind NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# having have VERB VBG advcl xxxx True False
# different different ADJ JJ amod xxxx True False
# physical physical NOUN NN amod xxxx True False
#
#
#  SPACE _SP
#  False False
# and and CCONJ CC cc xxx True True
# chemical chemical NOUN NN conj xxxx True False
# properties property NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# so so ADV RB advmod xx True True
# also also ADV RB advmod xxxx True True
# these these DET DT det xxxx True True
#
#
#  SPACE _SP
#  False False
# peculiar peculiar ADJ JJ amod xxxx True False
# fluids fluid NOUN NNS nsubj xxxx True False
# differ differ VERB VBP ROOT xxxx True False
# in in ADP IN prep xx True True
# kind kind NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# quality quality NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
#
#
#  SPACE _SP
#  False False
# chemical chemical NOUN NN compound xxxx True False
# action action NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# from from ADP IN prep xxxx True True
# each each DET DT det xxxx True True
# other other ADJ JJ pobj xxxx True True
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# As as SCONJ IN mark Xx True True
# the the DET DT det xxx True True
# food food NOUN NN nsubj xxxx True False
# passes pass VERB VBZ advcl xxxx True False
# through through ADP IN prep xxxx True True
# the the DET DT det xxx True True
# intestines intestine NOUN NNS pobj xxxx True False
#
#
#  SPACE _SP
#  False False
# from from ADP IN prep xxxx True True
# above above ADP IN advmod xxxx True True
# downward downward ADV RB pobj xxxx True False
# , , PUNCT , punct , False False
# those those DET DT det xxxx True True
# parts part NOUN NNS nsubjpass xxxx True False
#
#
#  SPACE _SP
#  False False
# of of ADP IN prep xx True True
# it -PRON- PRON PRP pobj xx True True
# which which DET WDT nsubjpass xxxx True True
# become become VERB VBP auxpass xxxx True True
# reduced reduce VERB VBN relcl xxxx True False
# to to ADP IN prep xx True True
# a a DET DT det x True True
# liquid liquid ADJ JJ nmod xxxx True False
#
#
#  SPACE _SP
#  False False
# state state NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# are be AUX VBP auxpass xxx True True
# successively successively ADV RB advmod xxxx True False
# removed remove VERB VBN ROOT xxxx True False
# by by ADP IN agent xx True True
# absorption absorption NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# and and CCONJ CC cc xxx True True
# taken take VERB VBN conj xxxx True False
# up up ADP RP prt xx True True
# into into ADP IN prep xxxx True True
# the the DET DT det xxx True True
# blood blood NOUN NN pobj xxxx True False
#
#
#  SPACE _SP
#  False False
# while while SCONJ IN mark xxxx True True
# the the DET DT det xxx True True
# remaining remain VERB VBG amod xxxx True False
# portion portion NOUN NN nsubj xxxx True False
# , , PUNCT , punct , False False
# which which DET WDT nsubj xxxx True True
# is be AUX VBZ relcl xx True True
# in in ADP IN advmod xx True True
# - - PUNCT HYPH punct - False False
# digestible digestible ADJ JJ acomp xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# together together ADV RB advmod xxxx True True
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# intestinal intestinal ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# secretions secretion NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# acquires acquire VERB VBZ advcl xxxx True False
# a a DET DT det x True True
# firmer firm ADJ JJR amod xxxx True False
# consistency consistency NOUN NN dobj xxxx True False
#
#
#  SPACE _SP
#  False False
# owing owe VERB VBG advcl xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# absorption absorption NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# fluids fluid NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
#
#
#  SPACE _SP
#  False False
# is be AUX VBZ auxpass xx True True
# finally finally ADV RB advmod xxxx True False
# discharged discharge VERB VBN conj xxxx True False
# as as SCONJ IN prep xx True True
# detrite detrite NOUN NN compound xxxx True False
# material material NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# by by ADP IN agent xx True True
# the the DET DT det xxx True True
# vermicular vermicular ADJ JJ compound xxxx True False
# action action NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# intestines intestine NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# In in ADP IN prep Xx True True
# the the DET DT det xxx True True
# lower low ADJ JJR amod xxxx True False
# order order NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# animals animal NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# digestive digestive ADJ JJ nmod xxxx True False
#
#
#  SPACE _SP
#  False False
# apparatus apparatus NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# more more ADV RBR advmod xxxx True True
# complex complex ADJ JJ acomp xxxx True False
# than than SCONJ IN prep xxxx True True
#
#
#  SPACE _SP
#  False False
# in in ADP IN prep xx True True
# man man NOUN NN pobj xxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# fowl fowl NOUN NN nsubj xxxx True False
# has have AUX VBZ ROOT xxx True True
# three three NUM CD nummod xxxx True True
# stomachs stomach NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# while while SCONJ IN mark xxxx True True
# some some DET DT nsubj xxxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# higher high ADJ JJR amod xxxx True False
# order order NOUN NN pobj xxxx True False
# have have AUX VBP advcl xxxx True True
# four four NUM CD dobj xxxx True True
# ; ; PUNCT : punct ; False False
#
#
#  SPACE _SP
#  False False
# while while SCONJ IN mark xxxx True True
# man man NOUN NN nsubj xxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# head head NOUN NN appos xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# animal animal NOUN NN compound xxxx True False
# creation creation NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# has have AUX VBZ advcl xxx True True
# but but CCONJ CC cc xxx True True
# two two NUM CD ROOT xxx True True
# . . PUNCT . punct . False False
# There there PRON EX expl Xxxxx True True
# is be AUX VBZ ROOT xx True True
# , , PUNCT , punct , False False
# however however ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# a a DET DT det x True True
# great great ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# similarity similarity NOUN NN attr xxxx True False
# between between ADP IN prep xxxx True True
# the the DET DT det xxx True True
# animal animal NOUN NN compound xxxx True False
# digestive digestive NOUN NN nmod xxxx True False
#
#
#  SPACE _SP
#  False False
# system system NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# that that DET DT conj xxxx True True
# of of ADP IN prep xx True True
# man man NOUN NN pobj xxx True False
# . . PUNCT . punct . False False
# In in ADP IN prep Xx True True
# the the DET DT det xxx True True
# human human ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# species specie NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# although although SCONJ IN mark xxxx True True
# the the DET DT det xxx True True
# digestive digestive ADJ JJ amod xxxx True False
# apparatus apparatus NOUN NN nsubj xxxx True False
#
#
#  SPACE _SP
#  False False
# is be AUX VBZ advcl xx True True
# simpler simple ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# in in ADP IN prep xx True True
# animals animal NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# still still ADV RB advmod xxxx True True
# it -PRON- PRON PRP nsubj xx True True
# is be AUX VBZ ROOT xx True True
# quite quite ADV RB advmod xxxx True True
#
#
#  SPACE _SP
#  False False
# complicated complicated ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# alimentary alimentary ADJ JJ amod xxxx True False
# canal canal NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
#
#
#  SPACE _SP
#  False False
# divided divide VERB VBN ROOT xxxx True False
# into into ADP IN prep xxxx True True
# different different ADJ JJ amod xxxx True False
# cavities cavity NOUN NNS pobj xxxx True False
# which which DET WDT nsubj xxxx True True
# communicate communicate VERB VBP relcl xxxx True False
#
#
#  SPACE _SP
#  False False
# with with ADP IN prep xxxx True True
# each each DET DT det xxxx True True
# other other ADJ JJ pobj xxxx True True
# by by ADP IN prep xx True True
# narrow narrow ADJ JJ amod xxxx True False
# openings opening NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# At at ADP IN prep Xx True True
# its -PRON- DET PRP$ poss xxx True True
# commencement commencement NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# we -PRON- PRON PRP nsubj xx True True
# find find VERB VBP ROOT xxxx True False
# the the DET DT det xxx True True
# cavity cavity NOUN NN dobj xxxx True False
#
#
#  SPACE _SP
#  False False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# mouth mouth NOUN NN pobj xxxx True False
# guarded guard VERB VBN acl xxxx True False
# at at ADP IN prep xx True True
# its -PRON- DET PRP$ poss xxx True True
# posterior posterior ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# extremity extremity NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# by by ADP IN prep xx True True
# a a DET DT det x True True
# muscular muscular ADJ JJ amod xxxx True False
# valve valve NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# isthmus isthmus NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# fauces fauce NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Through through ADP IN prep Xxxxx True True
# the the DET DT det xxx True True
# œsophagus œsophagus NOUN NN pobj xxxx True False
#
#
#  SPACE _SP
#  False False
# it -PRON- PRON PRP nsubj xx True True
# communicates communicate VERB VBZ ccomp xxxx True False
# iwth iwth ADP IN xcomp xxxx True False
# the the DET DT det xxx True True
# stomach stomach NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# which which DET WDT nsubjpass xxxx True True
# is be AUX VBZ auxpass xx True True
# guarded guard VERB VBN relcl xxxx True False
# at at ADP IN prep xx True True
# either either DET DT det xxxx True True
# extremity extremity NOUN NN pobj xxxx True False
#
#
#  SPACE _SP
#  False False
# by by ADP IN prep xx True True
# circular circular ADJ JJ amod xxxx True False
# folds fold NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# muscular muscular ADJ JJ amod xxxx True False
# fibres fibre NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# called call VERB VBN acl xxxx True False
#
#
#  SPACE _SP
#  False False
# respectively respectively ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# cardiac cardiac ADJ JJ amod xxxx True False
# and and CCONJ CC cc xxx True True
# pyloric pyloric ADJ JJ conj xxxx True False
# orifices orifice NOUN NNS dobj xxxx True False
# ; ; PUNCT : punct ; False False
#
#
#  SPACE _SP
#  False False
# then then ADV RB advmod xxxx True True
# come come VERB VB ROOT xxxx True False
# the the DET DT det xxx True True
# small small ADJ JJ amod xxxx True False
# intestines intestine NOUN NNS nsubj xxxx True False
# under under ADP IN prep xxxx True True
#
#
#  SPACE _SP
#  False False
# different different ADJ JJ amod xxxx True False
# forms form NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True True
# names name NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# owing owe VERB VBG advcl xxxx True False
# to to ADP IN prep xx True True
# their -PRON- DET PRP$ poss xxxx True True
#
#
#  SPACE _SP
#  False False
# respective respective ADJ JJ amod xxxx True False
# structures structure NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Thus thus ADV RB advmod Xxxx True True
# we -PRON- PRON PRP nsubj xx True True
# have have AUX VBP ROOT xxxx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# duodenum duodenum NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# jejunum jejunum NOUN NNS conj xxxx True False
# and and CCONJ CC cc xxx True True
# ileum ileum NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# In in ADP IN prep Xx True True
# the the DET DT det xxx True True
# duodenum duodenum NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# we -PRON- PRON PRP nsubj xx True True
# have have AUX VBP ROOT xxxx True True
# the the DET DT det xxx True True
# biliary biliary NOUN NN amod xxxx True False
#
#
#  SPACE _SP
#  False False
# and and CCONJ CC cc xxx True True
# pancreatic pancreatic ADJ JJ compound xxxx True False
# ducts duct NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# lastly lastly ADV RB advmod xxxx True False
# the the DET DT det xxx True True
# small small ADJ JJ amod xxxx True False
#
#
#  SPACE _SP
#  False False
# intestines intestine NOUN NNS nsubj xxxx True False
# together together ADV RB advmod xxxx True True
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# larger large ADJ JJR amod xxxx True False
# ones one NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# separated separate VERB VBD conj xxxx True False
# from from ADP IN prep xxxx True True
# the the DET DT det xxx True True
# smaller small ADJ JJR pobj xxxx True False
# by by ADP IN agent xx True True
# the the DET DT det xxx True True
# ileocoecal ileocoecal PROPN NNP amod xxxx True False
#
#
#  SPACE _SP
#  False False
# valve valve NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# which which DET WDT nsubj xxxx True True
# is be AUX VBZ relcl xx True True
# liable liable ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# become become VERB VB xcomp xxxx True True
#
#
#  SPACE _SP
#  False False
# closed close VERB VBN acomp xxxx True False
# up up ADP RP prt xx True True
# by by ADP IN agent xx True True
# indigestible indigestible ADJ JJ amod xxxx True False
# substances substance NOUN NNS pobj xxxx True False
# lodging lodge VERB VBG acl xxxx True False
#
#
#  SPACE _SP
#  False False
# in in ADP IN prep xx True True
# it -PRON- PRON PRP pobj xx True True
# , , PUNCT , punct , False False
# causing cause VERB VBG advcl xxxx True False
# death death NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Next next ADV RB advmod Xxxx True True
# are be AUX VBP ROOT xxx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# larger large ADJ JJR amod xxxx True False
# intestines intestine NOUN NNS attr xxxx True False
# , , PUNCT , punct , False False
# which which DET WDT nsubjpass xxxx True True
# are be AUX VBP auxpass xxx True True
# named name VERB VBN relcl xxxx True False
# respectively respectively ADV RB advmod xxxx True False
#
#
#  SPACE _SP
#  False False
# the the DET DT det xxx True True
# ascending ascend VERB VBG amod xxxx True False
# transverse transverse NOUN NN oprd xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
#
#
#  SPACE _SP
#  False False
# descending descend VERB VBG conj xxxx True False
# colon colon NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# at at ADP IN prep xx True True
# the the DET DT det xxx True True
# latter latter ADJ JJ amod xxxx True True
# end end NOUN NN pobj xxx True False
# of of ADP IN prep xx True True
#
#
#  SPACE _SP
#  False False
# which which DET WDT nsubj xxxx True True
# is be AUX VBZ relcl xx True True
# a a DET DT det x True True
# strong strong ADJ JJ amod xxxx True False
# muscular muscular ADJ JJ amod xxxx True False
# band band NOUN NN attr xxxx True False
# called call VERB VBN acl xxxx True False
#
#
#  SPACE _SP
#  False False
# the the DET DT det xxx True True
# sphincter sphincter NOUN NN oprd xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# which which DET WDT nsubj xxxx True True
# becomes become VERB VBZ conj xxxx True True
# diseased diseased ADJ JJ acomp xxxx True False
#
#
#  SPACE _SP
#  False False
# to to ADP IN prep xx True True
# an an DET DT det xx True True
# intense intense ADJ JJ amod xxxx True False
# degree degree NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# piles pile NOUN NNS pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# hemorrhoids hemorrhoid NOUN NNS appos xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
#
#
#
#
#  SPACE _SP
#
#  False False
# Having have VERB VBG aux Xxxxx True False
# thus thus ADV RB advmod xxxx True True
# given give VERB VBN advcl xxxx True False
# a a DET DT det x True True
# brief brief ADJ JJ amod xxxx True False
# description description NOUN NN dobj xxxx True False
#
#
#  SPACE _SP
#  False False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# digestive digestive ADJ JJ amod xxxx True False
# organs organ NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# in in ADP IN prep xx True True
# order order NOUN NN pobj xxxx True False
# to to PART TO aux xx True True
# better well ADV RBR advmod xxxx True False
#
#
#  SPACE _SP
#  False False
# understand understand VERB VB acl xxxx True False
# their -PRON- DET PRP$ poss xxxx True True
# uses use NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# let let VERB VB ROOT xxx True False
# us -PRON- PRON PRP nsubj xx True True
# glance glance VERB VB ccomp xxxx True False
# at at ADP IN prep xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# very very ADV RB advmod xxxx True True
# interesting interesting ADJ JJ amod xxxx True False
# process process NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# digestion digestion NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE _SP
#  False False
# When when ADV WRB advmod Xxxx True True
# food food NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
# introduced introduce VERB VBN advcl xxxx True False
# into into ADP IN prep xxxx True True
# the the DET DT det xxx True True
# mouth mouth NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
#
#
#  SPACE _SP
#  False False
# there there PRON EX expl xxxx True True
# is be AUX VBZ ROOT xx True True
# a a DET DT det x True True
# process process NOUN NN attr xxxx True False
# of of ADP IN prep xx True True
# secretion secretion NOUN NN pobj xxxx True False
# going go VERB VBG acl xxxx True False
# on on ADP RP prep xx True True
#
#
#  SPACE _SP
#  False False
# which which DET WDT nsubj xxxx True True
# continues continue VERB VBZ advcl xxxx True False
# more more ADV RBR dobj xxxx True True
# or or CCONJ CC cc xx True True
# less less ADV RBR conj xxxx True True
# through through ADP IN prep xxxx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP
#  False False
# entire entire ADJ JJ amod xxxx True False
# digestive digestive ADJ JJ amod xxxx True False
# tube tube NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
ass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Comparison to the OCR version of the document

# %%
files_list = os.listdir(os.path.join(data_dir, "ocr-generated"))

orig_documents = {}

for filename in sorted(files_list):
    if filename.startswith("HR1866"):
#         print(filename)
        with open(os.path.join(data_dir, "ocr-generated", filename), "r") as f:
            content = f.read()
        orig_documents[filename] = content

# %%
doc = nlp(orig_documents['HR18660801-V01-01-p1.txt'])

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Jcformcr ORG
# 1 CARDINAL
# BATTLE CREEK LOC
# MICH GPE
# AUGUST DATE
# 11166 DATE
# 1 CARDINAL
# H. S ORG
# ~.:I NORP
# ED PERSON
# One CARDINAL
# H. 8 PERSON
# LA Y1 llattle Creak ORG
# l1avc four ORG
# two CARDINAL
# mimals PERSON
# The alilllentary canal ORG
# municate PERSON
# ophagus PERSON
# 1~1 CARDINAL
# 1nto CARDINAL
# ilds PERSON
# ces · PERSON
# hed ORG
# 1st DATE
# 2nd DATE
# ~~cous CARDINAL
# 4t.h CARDINAL
# 5th ORDINAL
# 6th ORDINAL
# JUice ORG
# 4s CARDINAL
# vanous kmds PERSON
# jt PRODUCT
# inte~-larger PRODUCT
# ltrong muscular PERSON
# togethei NORP
# acquireR GPE
# detrite materi PERSON
# al PERSON
# venuiculat PERSON
# three CARDINAL
# 1 CARDINAL
# Ii Ii II Ii PRODUCT

# %%
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['THE Jcformcr', 'Ł', 'OUR PHYSiC1AN', 'NATURE', '_', '_', '_', 'VOL', 'BATTLE CREEK', 'MICH.', 'THE HEALTH REFORMER', 'PUl!ILISUED', 'Mff', '~TllLY AT', 'mut', 'Jra1tu-~rtarm ~nstitutc, RATTJ.K CRi,:EK, iHICH., H. S', '_ LAY1', 'l., ED', 'I', 'TOE', 'One Dnlh', "r per Ye1u1 tnTa.l'iRhly", 'Advance', 'Dr. H.', 'LA Y1 llattle Creak', '%', 'higher order', 'man', 'the head', 'minrn', 'l creation', 'a great \nsimilarity', 'the animal \ndigestive system', 'man', 'the human species', 'the digestive apparatus', 'it', 'The alilllentary canal', "ditl'ernut cavities", 'coru-\n(0 ti 9 inn l', 'municate', '~................................................................ openings', 'DIGESTION', 'its commencement', 'we', 'the cav-', 'the mouth', 'its posterior 11Y J.', 'Gc11LH', 'P. extremity', 'a muscular valve', 'isthmus', 'the \nfauces', 'the ces-', '~ess ~y ~h1ch, ophagus', 'it', 'tho \nfood', 'a form 1~1 wlnch 1t', 'either extremity', 'the blood', 'circular folds', 'muscular fibres', 'the way', 'food b', '~ilds', 'the body', 'ces', 'the \nsmall intestmes', 'This process', 'accompli', 'the ditf', 'rent forms', 'names', 'their teeth', 'the \nsahva', 'ld', 't', 'e respective structures', 'we', 'the \n~~cous membrane', 'the gastric duodenum', 'jejunum', 'ileum', 'JUICe', '_B', '_', 'the lnle', '; ancl', 'the duodenum', 'we', 'JUice', '_ _ and pancreatic ducts', 'lastly the srnall', 'food co1~s1sts', 'a m1xtur~', 'intestines', "the \nlal'ger o.ncs", 'vanous kmds', 'd1fterent physical', 'the smaller hy', 'the \nand chemical properties', 'these coccal valve', 'peculiar fluids', 'kind', 'quality', 'indigestible \nsubstances chemical action', 'death', 'Next \narc', 'the food', 'the inte~-larger intestines', 'tines', 'those parts', 'the asccn1ling transverse', 'it', 'a liquid descending colon', 'ot state', 'ab', 'ltrong muscular band', 'sorption', 'the blood', 'the sphincter', 'the remaining portion', 'an intense degree', 'piles', 'the intestinal \norrhoia")-secretions', 'acquireR', 'a brief description', 'the absorption', 'the lhlids', 'the digestive organs', 'order', 'detrite materi', 'their uses', 'us', 'the al', 'the venuiculat action', 'the intes', '-very interesting process', 'digestion', 'tines', 'food', 'the mouth', 'lower order', 'animals', 'a process', 'secretion', 'gcstive apparatus', 'I', 'man', 'The fowl', 'three stomachs', '1 entire digestive tube', 'The teeth arc', 'Ii Ii II Ii']
# Verbs: ['obey', 'live', 'diviue', "t'i", 'find', 'guard', 'be', 'commumcate', 'reduce', 'can', 'guard', 'absorb', 'take', 'call', 'waste', 'go', 'come', 'hed', 'rent', 'owe', 'have', 'separate', 'become', 'differ', 'close', 'e', 'cause', 'pass', 'name', 'asccn1le', 'become', 'reduce', 'descend', 'remove', 'call', 'take', 'become', 'remain', 'ease', 'have', 'give', 'owe', 'discharge', 'understand', 'let', 'glance', 'introduce', 'go', 'continue', 'set']

# %%
orig_doc_verbs = [token.lemma_ for token in doc if token.pos_ == "VERB"]

# %%
for sent in list(doc.sents):
    displacy.render(sent, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="77879bee17224de89168d5f0bcb9ab09-0" class="displacy" width="750" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77879bee17224de89168d5f0bcb9ab09-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77879bee17224de89168d5f0bcb9ab09-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77879bee17224de89168d5f0bcb9ab09-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77879bee17224de89168d5f0bcb9ab09-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77879bee17224de89168d5f0bcb9ab09-0-2" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77879bee17224de89168d5f0bcb9ab09-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,266.5 L398.0,254.5 382.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c66acc94fe254f07a81bdcae7b83e000-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5861d69e1f0a41b0a08168b5283b4945-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5c8846701e8c414c82e8dc464f741ff9-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b56cf70674a042c89e43c6c6c1d5cb5f-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2b834dcd65b4473fa4dd7db3f23be2f8-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6181c37c484940539f71e5f3f41b0832-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3d57083ec2654259bebc4e4d7c3377d3-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7b1007df150b448e812c042ac26dbbbb-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50
0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-5" stroke-width="2px" d="M1120,352.0 C1120,89.5 1620.0,89.5 1620.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-6" stroke-width="2px" d="M1295,352.0 C1295,177.0 1615.0,177.0 1615.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-7" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,354.0 L1462,342.0 1478,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-8" stroke-width="2px" d="M945,352.0 C945,2.0 1625.0,2.0 1625.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2784afec59fc4e1998e7b6ea186ec2dd-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1625.0,354.0 L1633.0,342
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="74cc8a303e61469e80efa18a0959cffa-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">teeth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">arc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">set</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# ,,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Ii</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Ii</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">II</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Ii</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-74cc8a303e61469e80efa18a0959cffa-0-7" stroke-width="2px" d="M770,264.5 C770,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-74cc8a303e61469e80efa18a0959cffa-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Let's compare the set of identified verbs

# %%
# https://www.geeksforgeeks.org/python-difference-two-lists/
def Diff(li1, li2):
    return list(set(li1) - set(li2)), list(set(li2) - set(li1))

# %%
Diff(doc_verbs, orig_doc_verbs)
# Out:
# (['consist',
#   'acquire',
#   'ascend',
#   'build',
#   'accomplish',
#   'lodge',
#   'communicate',
#   'publish',
#   'divide'],
#  ['commumcate',
#   'asccn1le',
#   'e',
#   'rent',
#   'diviue',
#   'hed',
#   'be',
#   "t'i",
#   'ease',
#   'waste'])

# %% [markdown]
# One of the strategies for dealing with messy OCR is to select only the nouns for tasks such as topic modeling.
